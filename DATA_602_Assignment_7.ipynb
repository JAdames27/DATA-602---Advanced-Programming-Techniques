# %% [markdown]
# Julian Adames-Ng
#
# DATA 602 - Advanced Programming Techniques
#
# Prof. Schettini
#
# Fall 2023
#
# Assignment #7

# %% [markdown]
# # Introduction
# In this section, please describe the dataset you are using. Include a link to the source of this data. You should also provide some explanation on why you choose this dataset.
#
# -The data set that I chose for this assignment is the weather.csv data set found on the provided github.  The link is below:
#
# https://github.com/data602sps/datasetspractice/blob/main/weather.csv
#
# I chose this data set because, I have an interest in atmospheric sciences and have worked with the Metpy package in Python to compute desired values relating to meteorology.

# %% [markdown]
# # Data Exploration
# Import your dataset into your .ipynb, create dataframes, and explore your data.

# %%
import pandas as pd

#import data from .csv file and store it as a data frame called df
df = pd.read_csv('weather.csv')

df
# Out:
#       Unnamed: 0 origin  year  month   day  hour   temp   dewp  humid  \
# 0              1    EWR  2013    1.0   1.0   0.0  37.04  21.92  53.97
# 1              2    EWR  2013    1.0   1.0   1.0  37.04  21.92  53.97
# 2              3    EWR  2013    1.0   1.0   2.0  37.94  21.92  52.09
# 3              4    EWR  2013    1.0   1.0   3.0  37.94  23.00  54.51
# 4              5    EWR  2013    1.0   1.0   4.0  37.94  24.08  57.04
# ...          ...    ...   ...    ...   ...   ...    ...    ...    ...
# 8714        8715    JFK  2013    9.0   2.0  20.0  75.20  73.40  94.14
# 8715        8716    JFK  2013   10.0  23.0  10.0  48.92  39.02  68.51
# 8716        8717    JFK  2013   10.0  23.0  11.0  48.92  39.02  68.51
# 8717        8718    JFK  2013   12.0  17.0   5.0  26.96  10.94  50.34
# 8718        8719    LGA  2013    8.0  22.0  22.0  75.92  66.92  73.68
#
#       wind_dir  wind_speed  wind_gust  precip  pressure  visib
# 0        230.0    10.35702  11.918651     0.0    1013.9   10.0
# ...

# %% [markdown]
# Include:
#
# Summary statistics means, medians, quartiles,
# Missing value information
# Any other relevant information about the dataset.

# %%
#use .describe() method to get summary statistics and print the output
print(df.describe())
# Out:
#         Unnamed: 0    year        month          day         hour  \
# count  8719.000000  8719.0  8718.000000  8718.000000  8718.000000
# mean   4360.000000  2013.0     6.506538    15.679628    11.515715
# std    2517.102832     0.0     3.439961     8.768250     6.916846
# min       1.000000  2013.0     1.000000     1.000000     0.000000
# 25%    2180.500000  2013.0     4.000000     8.000000     6.000000
# 50%    4360.000000  2013.0     7.000000    16.000000    12.000000
# 75%    6539.500000  2013.0     9.000000    23.000000    18.000000
# max    8719.000000  2013.0    12.000000    31.000000    23.000000
#
#               temp         dewp        humid     wind_dir   wind_speed  \
# count  8718.000000  8718.000000  8718.000000  8486.000000  8718.000000
# mean     55.484942    41.794184    62.863333   193.194674     9.335732
# std      18.345817    19.619776    19.572699   110.541333    12.328261
# min      10.940000    -9.040000    13.950000     0.000000     0.000000
# ...

# %% [markdown]
# # Data Wrangling
# Create a subset of your original data and perform the following.
#
# 1) Modify multiple column names.

# %%
#subset "df" with columns 'temp', 'dewp', 'humid', 'pressure'.  Assign to "df1".
df1 = df[['month','day','temp','dewp','humid','pressure']]

#reassign "df1" by renaming the columns
df1 = df1.rename(columns={"temp": "Temperature", "dewp": "Dewpoint Temperature", 'humid':'Relative Humidity', 'pressure' : 'Pressure'})

df1
# Out:
#       month   day  Temperature  Dewpoint Temperature  Relative Humidity  \
# 0       1.0   1.0        37.04                 21.92              53.97
# 1       1.0   1.0        37.04                 21.92              53.97
# 2       1.0   1.0        37.94                 21.92              52.09
# 3       1.0   1.0        37.94                 23.00              54.51
# 4       1.0   1.0        37.94                 24.08              57.04
# ...     ...   ...          ...                   ...                ...
# 8714    9.0   2.0        75.20                 73.40              94.14
# 8715   10.0  23.0        48.92                 39.02              68.51
# 8716   10.0  23.0        48.92                 39.02              68.51
# 8717   12.0  17.0        26.96                 10.94              50.34
# 8718    8.0  22.0        75.92                 66.92              73.68
#
#       Pressure
# 0       1013.9
# 1       1013.0
# 2       1012.6
# 3       1012.7
# 4       1012.8
# ...

# %% [markdown]
# 2) Look at the structure of your data – are any variables improperly coded? Such as strings or characters? Convert to correct structure if needed.
#
# 3) Fix missing and invalid values in data.
#
# 4) Create new columns based on existing columns or calculations.

# %%
#drop rows with invalid entries
df1 = df1.dropna()

df1
# Out:
#       month   day  Temperature  Dewpoint Temperature  Relative Humidity  \
# 0       1.0   1.0        37.04                 21.92              53.97
# 1       1.0   1.0        37.04                 21.92              53.97
# 2       1.0   1.0        37.94                 21.92              52.09
# 3       1.0   1.0        37.94                 23.00              54.51
# 4       1.0   1.0        37.94                 24.08              57.04
# ...     ...   ...          ...                   ...                ...
# 8713    7.0  31.0        71.06                 55.04              56.93
# 8715   10.0  23.0        48.92                 39.02              68.51
# 8716   10.0  23.0        48.92                 39.02              68.51
# 8717   12.0  17.0        26.96                 10.94              50.34
# 8718    8.0  22.0        75.92                 66.92              73.68
#
#       Pressure
# 0       1013.9
# 1       1013.0
# 2       1012.6
# 3       1012.7
# 4       1012.8
# ...

# %% [markdown]
# 5) Drop column(s) from your dataset.
#
# 6) Drop a row(s) from your dataset.

# %%
#drop dewpoint temperature column and last row
df1 = df1.drop(columns = ['Dewpoint Temperature'])

df1 = df1.drop(len(df1)-1)

df1
# Out:
#       month   day  Temperature  Relative Humidity  Pressure
# 0       1.0   1.0        37.04              53.97    1013.9
# 1       1.0   1.0        37.04              53.97    1013.0
# 2       1.0   1.0        37.94              52.09    1012.6
# 3       1.0   1.0        37.94              54.51    1012.7
# 4       1.0   1.0        37.94              57.04    1012.8
# ...     ...   ...          ...                ...       ...
# 8713    7.0  31.0        71.06              56.93    1020.4
# 8715   10.0  23.0        48.92              68.51    1008.1
# 8716   10.0  23.0        48.92              68.51    1008.5
# 8717   12.0  17.0        26.96              50.34    1023.9
# 8718    8.0  22.0        75.92              73.68    1011.9
#
# [7778 rows x 5 columns]

# %% [markdown]
# 7) Sort your data based on multiple variables.

# %%
#sort by decreasing Pressure values
df1 = df1.sort_values(by = ['Pressure'], ascending = False)

df1
# Out:
#       month   day  Temperature  Relative Humidity  Pressure
# 7979   11.0  30.0        28.04              57.79    1041.9
# 7978   11.0  30.0        24.98              62.55    1041.8
# 7977   11.0  30.0        23.00              64.81    1041.6
# 7980   11.0  30.0        30.92              55.99    1041.4
# 7976   11.0  30.0        24.08              61.94    1041.4
# ...     ...   ...          ...                ...       ...
# 733     1.0  31.0        44.06              46.73     994.2
# 723     1.0  31.0        62.06              83.54     994.1
# 732     1.0  31.0        46.04              53.33     992.3
# 726     1.0  31.0        62.06              86.29     986.4
# 727     1.0  31.0        62.06              89.70     983.9
#
# [7778 rows x 5 columns]

# %% [markdown]
# 8) Filter your data based on some condition.

# %%
#filter only June values
df2 = df1[df1['month'] == 6]

df2
# Out:
#       month   day  Temperature  Relative Humidity  Pressure
# 4112    6.0  21.0        71.96              45.87    1026.2
# 4111    6.0  21.0        68.00              54.66    1026.1
# 4114    6.0  21.0        78.08              41.86    1025.8
# 4110    6.0  21.0        64.04              67.46    1025.8
# 4115    6.0  21.0        78.98              42.00    1025.7
# ...     ...   ...          ...                ...       ...
# 3929    6.0  13.0        66.92              81.22     998.4
# 4288    6.0  28.0        84.92              54.90     998.4
# 4287    6.0  28.0        87.98              48.26     998.3
# 4289    6.0  28.0        84.02              58.65     998.0
# 3930    6.0  13.0        66.02              83.79     997.9
#
# [627 rows x 5 columns]

# %% [markdown]
# 11) Group your dataset by one column, and get the mean, min, and max values by group.

# %%
#using df1 #group by 'month' and found the mean
df3 = df1.groupby('month').mean()

df3
# Out:
#              day  Temperature  Relative Humidity     Pressure
# month
# 1.0    15.534351    34.766779          58.260519  1021.016794
# 2.0    14.486395    33.861531          59.501769  1016.275170
# 3.0    16.243722    40.051078          55.201640  1013.457607
# 4.0    15.471756    53.004763          51.583084  1020.420916
# 5.0    15.733229    63.100406          60.575601  1018.464899
# 6.0    15.717703    73.804211          63.731116  1013.587719
# 7.0    16.483670    81.280249          63.938974  1016.555988
# 8.0    16.011713    74.458917          64.033631  1016.679063
# 9.0    15.949405    66.919732          62.669315  1016.959524
# 10.0   16.192250    59.267988          63.366155  1018.108793
# 11.0   15.230534    44.130351          53.839756  1022.410687
# 12.0   16.021277    37.644812          66.102242  1019.955319

# %%
#group by 'month' and found the min
df4 = df1.groupby('month').min()

df4
# Out:
#        day  Temperature  Relative Humidity  Pressure
# month
# 1.0    1.0        10.94              20.87     983.9
# 2.0    1.0        15.98              24.40     999.1
# 3.0    1.0        26.06              17.64     998.1
# 4.0    1.0        30.92              13.95    1003.1
# 5.0    1.0        42.98              15.68    1004.7
# 6.0    1.0        55.04              26.40     997.9
# 7.0    1.0        64.04              28.60    1001.2
# 8.0    1.0        59.00              29.89    1005.7
# 9.0    1.0        48.02              27.23    1004.0
# 10.0   1.0        33.08              23.85    1003.2
# 11.0   1.0        21.02              16.15     995.1
# 12.0   1.0        17.96              28.93     997.9

# %%
#group by 'month' and found the max
df5 = df1.groupby('month').max()

df5
# Out:
#         day  Temperature  Relative Humidity  Pressure
# month
# 1.0    31.0        64.04             100.00    1034.4
# 2.0    28.0        55.94             100.00    1033.2
# 3.0    31.0        60.08              96.49    1029.7
# 4.0    30.0        84.02             100.00    1037.9
# 5.0    31.0        93.02             100.00    1032.3
# 6.0    30.0        93.92             100.00    1026.2
# 7.0    31.0       100.04              96.99    1027.1
# 8.0    31.0        89.96              96.99    1029.4
# 9.0    30.0        95.00              96.88    1031.0
# 10.0   31.0        89.06              96.93    1030.1
# 11.0   30.0        71.06             100.00    1041.9
# 12.0   30.0        69.98             100.00    1036.3

# %% [markdown]
# 12) Groupby()
# agg() or .apply()
# Group your dataset by two columns and then sort the aggregated results within the groups.
# You are free (and should) to add on to these questions. Please clearly indicate in your assignment your answers to these questions.

# %%
#group by 'month' and 'day' and sort values by 'Temperature'
df6 = df1.groupby(['month','day']).max().sort_values('Temperature', ascending = False)

df6
# Out:
#             Temperature  Relative Humidity  Pressure
# month day
# 7.0   19.0       100.04              79.42    1014.8
#       18.0       100.04              74.07    1018.5
#       15.0        96.98              79.12    1024.3
# 9.0   11.0        95.00              90.22    1019.8
# 7.0   6.0         95.00              84.46    1020.6
# ...                 ...                ...       ...
# 12.0  17.0        28.04              84.87    1024.1
# 1.0   26.0        28.04              87.47    1025.0
#       25.0        24.08              58.34    1030.4
#       24.0        24.08              70.07    1028.5
#       23.0        19.94              50.37    1024.9
#
# [364 rows x 3 columns]

# %% [markdown]
# # Conclusions
# After exploring your dataset, provide a short summary of what you noticed from this dataset. What would you explore further with more time?
#
# -This data made me want to explore the National Oceanic and Atmospheric Administration's website for more data on the atmosphere.  If I could, I would use the temperature, pressure, and relative humidity data to compute Convective Available Potential Energy on given days using a built in Python code using the metpy package.  Metpy deals with meteorological data and provides a wide range of uses in the atmospheric sciences.
